# %%
import numpy as np
import matplotlib.pyplot as plt

# Let's create a some randon data using linspace
x = np.linspace(0, 100, 50) # creates a range of 50 numbers evenly spaced between 0 and 100
delta = np.random.uniform(-10, 10, x.size)
y = 0.5*x + 3 + delta

plt.scatter(x, y)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Let's change the shape of x array to the format expected by sklearn
x = x.reshape((-1, 1))
x.shape

# Let's create the model object using LinearRegression
model = LinearRegression()

# Fit our model to our input data x and y
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Get our model paramters
print('Y Intercept:', model.intercept_)
print('Gradient:', model.coef_)

# Store all predictions in y_pred
y_pred = model.predict(x)

plt.scatter(x, y)
plt.plot(x, y_pred, color='r')
# Out:
# Y Intercept: 1.218958633906709
# Gradient: [0.53767419]

# %% [markdown]
# # 4 - Degree Polynomial

# %%
# Fitting Polynomial Regression to the dataset 
# Fitting the Polynomial Regression model on two components X and y.
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 4) 
model_Poly = poly.fit_transform(x) 
  
poly.fit(model_Poly, y) 
lin2 = LinearRegression() 
lin2.fit(model_Poly, y) 

# Visualising the Polynomial Regression results 
plt.scatter(x, y, color = 'blue') 
  
plt.plot(x, lin2.predict(poly.fit_transform(x)), color = 'red') 
plt.title('Polynomial Regression') 
plt.xlabel('Temperature') 
plt.ylabel('Pressure') 
  
plt.show()

# %%
# Fitting Polynomial Regression to the dataset 
# Fitting the Polynomial Regression model on two components X and y.
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 8) 
model_Poly = poly.fit_transform(x) 
  
poly.fit(model_Poly, y) 
lin2 = LinearRegression() 
lin2.fit(model_Poly, y) 

# Visualising the Polynomial Regression results 
plt.scatter(x, y, color = 'blue') 
  
plt.plot(x, lin2.predict(poly.fit_transform(x)), color = 'red') 
plt.title('Polynomial Regression') 
plt.xlabel('Temperature') 
plt.ylabel('Pressure') 
  
plt.show()

# %% [markdown]
# # Add some Outliers

# %%
import numpy as np
import matplotlib.pyplot as plt

# Let's create a some randon data using linspace
x = np.linspace(0, 100, 50) # creates a range of 50 numbers evenly spaced between 0 and 100
delta = np.random.uniform(-10, 10, x.size)
y = 0.5*x + 3 + delta

plt.scatter(x, y)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Let's create a some randon data using linspace
x = np.linspace(0, 100, 50) # creates a range of 50 numbers evenly spaced between 0 and 100
delta = np.random.uniform(-10, 10, x.size)
y = 0.5*x + 3 + delta
x = x.reshape((-1, 1))
x = np.append(x, 61.0)
y = np.append(y, 65.0)
x = np.array(x).reshape(-1, 1)
y = np.array(y)
plt.scatter(x, y)

# %%
x.sort()
x
# Out:
# array([[  0.        ],
#        [  2.04081633],
#        [  4.08163265],
#        [  6.12244898],
#        [  8.16326531],
#        [ 10.20408163],
#        [ 12.24489796],
#        [ 14.28571429],
#        [ 16.32653061],
#        [ 18.36734694],
#        [ 20.40816327],
#        [ 22.44897959],
#        [ 24.48979592],
#        [ 26.53061224],
#        [ 28.57142857],
#        [ 30.6122449 ],
#        [ 32.65306122],
#        [ 34.69387755],
#        [ 36.73469388],
#        [ 38.7755102 ],
#        [ 40.81632653],
#        [ 42.85714286],
#        [ 44.89795918],
#        [ 46.93877551],
#        [ 48.97959184],
#        [ 51.02040816],
#        [ 53.06122449],
#        [ 55.10204082],
#        [ 57.14285714],
#        [ 59.18367347],
#        [ 61.2244898 ],
#        [ 63.26530612],
#        [ 65.30612245],
#        [ 67.34693878],
#        [ 69.3877551 ],
#        [ 71.42857143],
#        [ 73.46938776],
#        [ 75.51020408],
#        [ 77.55102041],
#        [ 79.59183673],
#        [ 81.63265306],
#        [ 83.67346939],
#        [ 85.71428571],
#        [ 87.75510204],
#        [ 89.79591837],
#        [ 91.83673469],
#        [ 93.87755102],
#        [ 95.91836735],
#        [ 97.95918367],
#        [100.        ],
#        [ 61.        ]])

# %%
# Fitting Polynomial Regression to the dataset 
# Fitting the Polynomial Regression model on two components X and y.
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 9) 
model_Poly = poly.fit_transform(x) 
  
poly.fit(model_Poly, y) 
lin2 = LinearRegression() 
lin2.fit(model_Poly, y) 

# Visualising the Polynomial Regression results 
plt.scatter(x, y, color = 'blue') 
  
plt.plot(x, lin2.predict(poly.fit_transform(x)), color = 'red') 
plt.title('Polynomial Regression') 
plt.xlabel('Temperature') 
plt.ylabel('Pressure') 
  
plt.show()

# %%
y
# Out:
# array([12.04603253,  5.57158682,  7.41130851, -3.58795024,  1.92384962,
#         1.79663971,  5.00540588, 16.19539139, 10.156453  , 15.13138638,
#         9.41855659, 23.18975741,  8.21414052, 21.35089542, 13.2455652 ,
#        19.50193356, 28.44525375, 23.85293797, 20.77647324, 14.85089268,
#        16.60852195, 29.48610798, 31.01577939, 25.32338695, 32.84632011,
#        23.98984961, 33.81899137, 36.2475454 , 38.75789273, 40.74528962,
#        42.19528956, 28.0635806 , 35.16014641, 28.814761  , 40.42410223,
#        40.32582716, 40.33981489, 31.40018949, 42.55987919, 51.00667989,
#        50.78837335, 40.28481388, 53.07913951, 54.99223657, 38.99632517,
#        44.92466724, 43.69959953, 56.25799696, 59.25716375, 60.58055758,
#        60.        ])
